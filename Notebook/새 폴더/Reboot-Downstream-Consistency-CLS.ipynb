# %%
import torch

# %%
a = torch.load('/workspace/sunggu/1.Hemorrhage/models/MTL/Upsteam/[UpTASK]Hemo_resnet50_Ours-recon_simple-NEW/epoch_950_best_metric_model.pth')

# %%
for i in a['model_state_dict']:
    print(i)
# Out:
# encoder.conv1.weight
# encoder.bn1.weight
# encoder.bn1.bias
# encoder.bn1.running_mean
# encoder.bn1.running_var
# encoder.bn1.num_batches_tracked
# encoder.layer1.0.conv1.weight
# encoder.layer1.0.bn1.weight
# encoder.layer1.0.bn1.bias
# encoder.layer1.0.bn1.running_mean
# encoder.layer1.0.bn1.running_var
# encoder.layer1.0.bn1.num_batches_tracked
# encoder.layer1.0.conv2.weight
# encoder.layer1.0.bn2.weight
# encoder.layer1.0.bn2.bias
# encoder.layer1.0.bn2.running_mean
# encoder.layer1.0.bn2.running_var
# encoder.layer1.0.bn2.num_batches_tracked
# encoder.layer1.0.conv3.weight
# encoder.layer1.0.bn3.weight
# encoder.layer1.0.bn3.bias
# encoder.layer1.0.bn3.running_mean
# encoder.layer1.0.bn3.running_var
# encoder.layer1.0.bn3.num_batches_tracked
# encoder.layer1.0.downsample.0.weight
# encoder.layer1.0.downsample.1.weight
# encoder.layer1.0.downsample.1.bias
# encoder.layer1.0.downsample.1.running_mean
# encoder.layer1.0.downsample.1.running_var
# ...

# %%
# !nvidia-smi

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "3"
# Out:
# Tue Aug 10 13:45:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     Off  | 00000000:18:00.0 Off |                  Off |
# | 40%   65C    P2   273W / 260W |   7063MiB / 48601MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python train.py \
--model-name 'Downtask_Cls_Old_model' \
--test-name '[Ablation]freeze_encoder_from_Consistency_16x16_GAP' \
--batch-size 60 \
--epochs 1000 \
--min-lr 5e-6 \
--lr 1e-5 \
--training-stream 'Downstream'\
--training-mode 'other_cls' \
--data-set 'Hemo_Downtask' \
--output '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS' \
--validate-every 1 \
--num_workers 8 \
--multi-gpu-mode 'DataParallel' \
--end2end "False" \
--pin-mem \
--resume '/workspace/sunggu/1.Hemorrhage/models/MTL/[DownTASK]Hemo_resnet50_[Classification]_freeze_encoder_LSTM_Consistency_16_16_GAP/epoch_4_best_metric_model.pth' \
--start_epoch 0
# --pretrained '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/mtl+consist+recon/epoch_980_checkpoint.pth' \
# Out:
# Not using distributed mode
# ***********************************************
# *           Training Mode is  other_cls       *
# ***********************************************
# Dataset Name:  Hemo_Downtask
# ---------- Model ----------
# Resume From:  /workspace/sunggu/1.Hemorrhage/models/MTL/[DownTASK]Hemo_resnet50_[Classification]_freeze_encoder_LSTM_Consistency_16_16_GAP/epoch_4_best_metric_model.pth
# Output To:  /workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS
# Number of GPUs:  1
# ---------- Optimizer ----------
# Learning Rate:  1e-05
# Weight Decay:  0.05
# Batchsize:  60
# Loading dataset ....
# Train [Total]  number =  1068
# Train [Hemo]   number =  747
# Train [Normal] number =  321
# Valid [Total]  number =  135
# Valid [Hemo]   number =  35
# Valid [Normal] number =  100
# Creating model: Downtask_Cls_Old_model
# Number of Learnable Params: 33216193
# Loading... Resume
# Epoch:  4  Best Metric ==>  0.930032284274179
# ...

# %%
import glob

log = glob.glob('/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/log.txt')

# %%
lines = open(log[0], 'r').read().splitlines()

# %%
import glob

def read_log(path):
    log_list = []
    lines = open(path, 'r').read().splitlines() 
    for i in range(len(lines)):
        exec('log_list.append('+lines[i] + ')')
    return  log_list

# %%
log_list = read_log(path = '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/log.txt')

# %%
train_lr   = [ log_list[i]['train_lr'] for i in range(len(log_list)) ]
train_loss = [ log_list[i]['train_loss'] for i in range(len(log_list)) ]
valid_loss = [ log_list[i]['valid_loss'] for i in range(len(log_list)) ]
valid_AUC  = [ log_list[i]['valid_AUC'] for i in range(len(log_list)) ]
valid_Acc  = [ log_list[i]['valid_Acc'] for i in range(len(log_list)) ]
valid_Sen  = [ log_list[i]['valid_Sen'] for i in range(len(log_list)) ]
valid_Spe  = [ log_list[i]['valid_Spe'] for i in range(len(log_list)) ]
epoch      = [ log_list[i]['epoch'] for i in range(len(log_list)) ]

# %%
import matplotlib.pyplot as plt 

plt.plot(train_loss)

# %%
plt.plot(valid_loss)

# %%
import numpy as np

np.argmin(valid_loss)
# Out:
# 153

# %%
valid_loss[150: 158]
# Out:
# [0.33392563687930643,
#  0.3368740664419925,
#  0.30977819920862437,
#  0.28288739151062653,
#  0.3394236255027526,
#  0.3377487794582353,
#  0.35807115754448915,
#  0.31099569998655674]

# %%
for i in np.argsort(valid_loss):
    print("Epoch = %5s" %i, "| LOSS = %.3f" %valid_loss[i], "| AUC = %.3f" %valid_AUC[i], "| ACC = %.3f" %valid_Acc[i])
# Out:
# Epoch =   153 | LOSS = 0.283 | AUC = 0.982 | ACC = 0.867
# Epoch =   142 | LOSS = 0.288 | AUC = 0.983 | ACC = 0.867
# Epoch =   176 | LOSS = 0.289 | AUC = 0.983 | ACC = 0.867
# Epoch =   118 | LOSS = 0.301 | AUC = 0.983 | ACC = 0.867
# Epoch =   107 | LOSS = 0.303 | AUC = 0.983 | ACC = 0.867
# Epoch =    91 | LOSS = 0.304 | AUC = 0.983 | ACC = 0.867
# Epoch =    68 | LOSS = 0.305 | AUC = 0.981 | ACC = 0.881
# Epoch =   145 | LOSS = 0.306 | AUC = 0.983 | ACC = 0.859
# Epoch =   192 | LOSS = 0.306 | AUC = 0.983 | ACC = 0.852
# Epoch =   104 | LOSS = 0.306 | AUC = 0.983 | ACC = 0.867
# Epoch =    95 | LOSS = 0.307 | AUC = 0.983 | ACC = 0.859
# Epoch =   129 | LOSS = 0.309 | AUC = 0.983 | ACC = 0.867
# Epoch =   152 | LOSS = 0.310 | AUC = 0.983 | ACC = 0.867
# Epoch =   180 | LOSS = 0.310 | AUC = 0.982 | ACC = 0.867
# Epoch =   178 | LOSS = 0.310 | AUC = 0.983 | ACC = 0.867
# Epoch =   131 | LOSS = 0.310 | AUC = 0.983 | ACC = 0.859
# ...

# %%
for i in np.argsort(valid_AUC)[::-1]:
    print("Epoch = %5s" %i, "| AUC = %.3f" %valid_AUC[i], "| ACC = %.3f" %valid_Acc[i], "| LOSS = %.3f" %valid_loss[i])
# Out:
# Epoch =   127 | AUC = 0.984 | ACC = 0.859 | LOSS = 0.312
# Epoch =   155 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.338
# Epoch =    89 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.330
# Epoch =    92 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.320
# Epoch =    93 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.319
# Epoch =    94 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.317
# Epoch =    95 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.307
# Epoch =    98 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.338
# Epoch =   162 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.346
# Epoch =   130 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.314
# Epoch =   131 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.310
# Epoch =   132 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.323
# Epoch =   145 | AUC = 0.983 | ACC = 0.859 | LOSS = 0.306
# Epoch =   164 | AUC = 0.983 | ACC = 0.867 | LOSS = 0.319
# Epoch =   163 | AUC = 0.983 | ACC = 0.867 | LOSS = 0.323
# Epoch =   159 | AUC = 0.983 | ACC = 0.867 | LOSS = 0.337
# ...

# %%
glob.glob('/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/*')
# Out:
# ['/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_0_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/log.txt',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_1_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_2_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_3_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_4_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_5_checkpoint.pth',
#  '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_6_checkpoint.pth',
# ...

# %%
# !python test.py \
--model-name 'Downtask_Cls_Old_model' \
--test-name '[Ablation]freeze_encoder_from_Consistency_16x16_GAP' \
--engine-option 'original' \
--save-path '/workspace/sunggu/1.Hemorrhage/scripts study/predictions/Paper/' \
--test-data-name 'Asan' \
--training-stream 'Downstream'\
--training-mode '3d_cls' \
--data-set 'Hemo_Downtask' \
--num_workers 8 \
--resume '/workspace/sunggu/1.Hemorrhage/scripts study/checkpoints/Reboot_Downstream_Consistency_CLS/epoch_153_checkpoint.pth' \
--end2end "False" \
--pin-mem
# Out:
# Loading dataset ....
# Test [Total]  number =  130
# Test [Hemo]   number =  30
# Test [Normal] number =  100
# Creating model: Downtask_Cls_Old_model
# Number of Learnable Params: 33216193
# Loading... Resume
# Epoch:  153  Best Metric ==>  0.9836924868957484
# TEST:  [  0/130]  eta: 0:04:51  loss: 0.0477 (0.0477)  time: 2.2398  data: 1.7698  max mem: 212
# TEST:  [ 10/130]  eta: 0:01:12  loss: 0.0022 (0.0576)  time: 0.6014  data: 0.1610  max mem: 216
# TEST:  [ 20/130]  eta: 0:00:54  loss: 0.0011 (0.0461)  time: 0.4038  data: 0.0001  max mem: 216
# TEST:  [ 30/130]  eta: 0:00:46  loss: 0.0103 (0.1216)  time: 0.3883  data: 0.0001  max mem: 216
# TEST:  [ 40/130]  eta: 0:00:40  loss: 0.0269 (0.1207)  time: 0.4083  data: 0.0001  max mem: 216
# TEST:  [ 50/130]  eta: 0:00:36  loss: 0.0243 (0.1348)  time: 0.4529  data: 0.0001  max mem: 216
# TEST:  [ 60/130]  eta: 0:00:33  loss: 0.0737 (0.3037)  time: 0.5433  data: 0.0001  max mem: 216
# ...
